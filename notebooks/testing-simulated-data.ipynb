# %% [markdown]
# # Training and validating on simulated data
#
# In this notebook we go through the construction of a training and a testing dataset as has been done in the article.
#
# We then train our model and finally validate it with the testing dataset.

# %%
import numpy as np
import mccd.auxiliary_fun as mccd_aux
import mccd
from astropy.io import fits

import random

import matplotlib.pyplot as plt
import matplotlib as mpl
from mpl_toolkits.axes_grid1 import make_axes_locatable
from matplotlib.colors import ListedColormap, LinearSegmentedColormap

# %%
plt.rc('text', usetex=True)
font = {'family' : 'serif',
        'weight' : 'bold',
        'size'   : 20}
mpl.rc('font', **font)

plot_style = {
                'figure.figsize': (6,6),
                'figure.dpi': 100,
                'figure.autolayout':True,
                'lines.linewidth': 4,
                'lines.linestyle': '-',
                'lines.marker': 'o',
                'lines.markersize': 10,
                'legend.fontsize': 20,
                'legend.loc': 'best',
                'axes.titlesize': 24,
                'axes.grid': False,
                'axes.grid.which': 'major',
                'axes.grid.axis': 'both'}
mpl.rcParams.update(plot_style)

def plot_fun(star_img, cmap='gist_stern'):
    fig = plt.figure()
    ax1 = fig.add_subplot(111)
    im1 = ax1.imshow(star_img, interpolation='None',cmap=cmap)
    divider = make_axes_locatable(ax1)
    cax = divider.append_axes("right", size="5%", pad=0.05)
    cbar = fig.colorbar(im1, cax=cax, extend='both')
    cbar.minorticks_on()
    fig.tight_layout()
    ax1.set_xticks([]);ax1.set_yticks([])
    ax1.axis('off')
    plt.show()

loc2glob = mccd.mccd_utils.Loc2Glob()

# Pre-defined colormap
top = mpl.cm.get_cmap('Oranges_r', 128)
bottom = mpl.cm.get_cmap('Blues', 128)
newcolors = np.vstack((top(np.linspace(0, 1, 128)),
                       bottom(np.linspace(0, 1, 128))))
newcmp = ListedColormap(newcolors, name='OrangeBlue')

def plot_ccds_fun(positions,mom,title):
    fig = plt.figure(figsize=(8, 8))
    ax1 = fig.add_subplot(111)
    for ccd_it in range(40):
        xs,ys = loc2glob.shift_coord(ccd_it)
        rect = mpl.patches.Rectangle((xs,ys),2048,4612,linewidth=1,edgecolor='r',facecolor='none')
        ax1.add_patch(rect)

    im1 = ax1.scatter(positions[:, 0], positions[:, 1], s=5,c=mom, marker='*', cmap=newcmp)
    divider = make_axes_locatable(ax1)
    cax = divider.append_axes('right', size='5%', pad=0.05)
    fig.colorbar(im1, cax=cax, orientation='vertical')
    ax1.set_xticks([]);ax1.set_yticks([])
    ax1.axis('off')
    ax1.set_title(title)
    plt.show()

# %% [markdown]
# # Generate training and testing datasets

# %%
input_pos_path = './../data/sim_inputs/train_positions.npy'
input_ccd_path = './../data/sim_inputs/train_ccd_list.npy'
output_path = './../data/mccd_inputs/'

sim_dataset_generator = mccd_aux.GenerateSimDataset(input_pos_path, input_ccd_path, output_path)

sim_dataset_generator.load_data()
# Posibility to define the simulation parameters
sim_dataset_generator.generate_train_data()  # Using default parameters
# Defining the testing grid
sim_dataset_generator.generate_test_data(x_grid=5, y_grid=10)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-ff0609d47427> in <module>
#       7 sim_dataset_generator.load_data()
#       8 # Posibility to define the simulation parameters
# ----> 9 sim_dataset_generator.generate_train_data()  # Using default parameters
#      10 # Defining the testing grid
#      11 sim_dataset_generator.generate_test_data(x_grid=5, y_grid=10)
#
# ~/opt/miniconda3/envs/denoising/lib/python3.9/site-packages/mccd-0.0.4-py3.9.egg/mccd/auxiliary_fun.py in generate_train_data(self, sigma, image_size, psf_flux, beta_psf, pix_scale, desired_SNR, catalog_id)
#     162             # Define intrapixel shift (uniform distribution in [-0.5,0.5])
#     163             rand_shift = np.random.rand(2) - 0.5
# --> 164             psf.drawImage(image=noisy_image_epsf, offset=rand_shift,
#     165                           scale=pix_scale)
#     166
#
# ~/opt/miniconda3/envs/denoising/lib/python3.9/site-packages/galsim/gsobject.py in drawImage(self, image, nx, ny, bounds, scale, wcs, dtype, method, area, exptime, gain, add_to_image, center, use_true_center, offset, n_photons, rng, max_extra_noise, poisson_flux, sensor, surface_ops, n_subsample, maxN, save_photons, setup_only)
#    1730                 added_photons = prof.drawReal(draw_image, add)
#    1731             else:
# -> 1732                 added_photons = prof.drawFFT(draw_image, add)
#    1733
#    1734             if sensor is not None:
#
# ~/opt/miniconda3/envs/denoising/lib/python3.9/site-packages/galsim/gsobject.py in drawFFT(self, image, add_to_image)
#    1953
#    1954         kimage, wrap_size = self.drawFFT_makeKImage(image)
# -> 1955         self._drawKImage(kimage)
#    1956         return self.drawFFT_finish(image, kimage, wrap_size, add_to_image)
#    1957
#
# ~/opt/miniconda3/envs/denoising/lib/python3.9/site-packages/galsim/utilities.py in f(*args, **kwargs)
#    1699         @functools.wraps(self.mthd, assigned=('__name__','__module__'))
#    1700         def f(*args, **kwargs):
# -> 1701             return self.mthd(obj, *args, **kwargs)
#    1702         return self.use_parent_doc(f, parfunc)
#    1703
#
# ~/opt/miniconda3/envs/denoising/lib/python3.9/site-packages/galsim/convolve.py in _drawKImage(self, image)
#     423     @doc_inherit
#     424     def _drawKImage(self, image):
# --> 425         self.obj_list[0]._drawKImage(image)
#     426         if len(self.obj_list) > 1:
#     427             im1 = image.copy()
#
# ~/opt/miniconda3/envs/denoising/lib/python3.9/site-packages/galsim/utilities.py in f(*args, **kwargs)
#    1699         @functools.wraps(self.mthd, assigned=('__name__','__module__'))
#    1700         def f(*args, **kwargs):
# -> 1701             return self.mthd(obj, *args, **kwargs)
#    1702         return self.use_parent_doc(f, parfunc)
#    1703
#
# ~/opt/miniconda3/envs/denoising/lib/python3.9/site-packages/galsim/transform.py in _drawKImage(self, image)
#     518     @doc_inherit
#     519     def _drawKImage(self, image):
# --> 520         self._sbp.drawK(image._image, image.scale)
#     521
#     522
#
# KeyboardInterrupt:

# %%
input_pos_path = './../data/sim_inputs/train_positions.npy'
input_ccd_path = './../data/sim_inputs/train_ccd_list.npy'
output_path = './../data/mccd_inputs/'

# Get the dataset paths
ext = '.fits'
catalog_id = 1111111

train_cat_path = output_path + 'train_star_selection-' + str(catalog_id) + ext
test_cat_path = output_path + 'test_star_selection-' + str(catalog_id) + ext

# %% [markdown]
# # Check the trainiung dataset

# %%
train_cat = fits.open(train_cat_path)[1]

# %%
pos = train_cat.data['GLOB_POSITION_IMG_LIST']
#plot_ccds_fun(pos,train_cat.data['TRUE_E1_HSM'],'e1 star positions')
#plot_ccds_fun(pos,train_cat.data['TRUE_E2_HSM'],'e2 star positions')
#plot_ccds_fun(pos,2.*train_cat.data['TRUE_SIG_HSM']**2,'R2 star positions')

# %%
# Load the data
train_cat = fits.open(train_cat_path)

# %% [markdown]
# # Prepare for the training
#
# We need to prepare the elements we will feed the MCCD algorithm.
#
# - Each input should be a list of elements.
# - Each position in the list will correspond to the data from one CCD.
# - The CCD id of each position should be included in the ``ccd_list``.
#
#
# - Data in fits file are concatenated over the first dimension into a large np.ndarray.
# - We need to split the data to have it assigned for the corresponding CCD.

# %%
train_cat[1].columns
# Out:
# ColDefs(
#     name = 'VIGNET_LIST'; format = '2601D'; dim = '(51, 51)'
#     name = 'GLOB_POSITION_IMG_LIST'; format = '2D'; dim = '(2,)'
#     name = 'MASK_LIST'; format = '2601D'; dim = '(51, 51)'
#     name = 'CCD_ID_LIST'; format = '1D'
#     name = 'TRUE_E1_HSM'; format = '1D'
#     name = 'TRUE_E2_HSM'; format = '1D'
#     name = 'TRUE_SIG_HSM'; format = '1D'
# )

# %%
# Extract the data from the fits catalog 
positions = np.copy(train_cat[1].data['GLOB_POSITION_IMG_LIST'])
stars = np.copy(train_cat[1].data['VIGNET_LIST'])
ccds = np.copy(train_cat[1].data['CCD_ID_LIST']).astype(int)
ccds_unique = np.unique(np.copy(train_cat[1].data['CCD_ID_LIST'])).astype(int)
# Generate the masks
masks = mccd.utils.handle_SExtractor_mask(stars,thresh=-1e5)

# Generate the list format needed by the MCCD package
pos_list = [positions[ccds == ccd] for ccd in ccds_unique]
star_list = [mccd.utils.rca_format(stars[ccds == ccd]) for ccd in ccds_unique]
mask_list = [mccd.utils.rca_format(masks[ccds == ccd]) for ccd in ccds_unique]
ccd_list = [ccds[ccds == ccd].astype(int) for ccd in ccds_unique]
ccd_list = [np.unique(_list)[0].astype(int) for _list in ccd_list]
SNR_weight_list = None  # We wont use any weighting technique as the SNR is constant over the Field of View

# %% [markdown]
# # MCCD train parameters

# %%
# Parameters

# MCCD instance
n_comp_loc = 4
d_comp_glob = 6
filters = None
ksig_loc = 0
ksig_glob = 0

# MCCD fit
psf_size = 6.2
psf_size_type = 'R2'
n_eigenvects = 5
n_iter_rca = 1
nb_iter_glob = 2 
nb_iter_loc = 2
nb_subiter_S_loc = 300
nb_subiter_A_loc = 500
nb_subiter_S_glob = 100
nb_subiter_A_glob = 200
loc_model = 'hybrid'


# Build the paramter dictionaries
mccd_inst_kw = {'n_comp_loc': n_comp_loc, 'd_comp_glob': d_comp_glob,
                'filters': filters,       'ksig_loc': ksig_loc,
                'ksig_glob':ksig_glob}

mccd_fit_kw = {'psf_size': psf_size,                  'psf_size_type':psf_size_type,
              'n_eigenvects': n_eigenvects,          'nb_iter':n_iter_rca,
              'nb_iter_glob':nb_iter_glob,           'nb_iter_loc':nb_iter_loc,
              'nb_subiter_S_loc':nb_subiter_S_loc,   'nb_subiter_A_loc':nb_subiter_A_loc,
              'nb_subiter_S_glob':nb_subiter_S_glob, 'nb_subiter_A_glob':nb_subiter_A_glob,
              'loc_model':loc_model}

# %% [markdown]
# # Launch the training
#
# - Then save the fitted model

# %%
# Instanciate the class
mccd_instance = mccd.MCCD(**mccd_inst_kw, verbose=True)
# Launch the training
S, A_loc, A_glob, alpha, pi = mccd_instance.fit(star_list, pos_list, ccd_list, mask_list,
                                                SNR_weight_list, **mccd_fit_kw)

fitted_model_path = output_path + '/fitted_model' + str(catalog_id)
mccd_instance.quicksave(fitted_model_path)
# Out:
# Running basic initialization tasks...
# ... Done.
# Constructing local spatial constraint...
# /Users/oa265351/opt/miniconda3/envs/denoising/lib/python3.9/site-packages/mccd-0.0.4-py3.9.egg/mccd/utils.py:523: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   self.VT = np.vstack((eigenvect for eigenvect in list_eigenvects))
# ... Done.
# Building position polynomials...
# ... Done.
# WARNING: Making input data immutable.
# WARNING: Making input data immutable.
# WARNING: Making input data immutable.
# WARNING: Making input data immutable.
# WARNING: Making input data immutable.
# WARNING: Making input data immutable.
# WARNING: Making input data immutable.
# WARNING: Making input data immutable.
# WARNING: Making input data immutable.
# WARNING: Making input data immutable.
# WARNING: Making input data immutable.
# WARNING: Making input data immutable.
# WARNING: Making input data immutable.
# WARNING: Making input data immutable.
# WARNING: Making input data immutable.
# WARNING: Making input data immutable.
# WARNING: Making input data immutable.
# WARNING: Making input data immutable.
# WARNING: Making input data immutable.
# WARNING: Making input data immutable.
# WARNING: Making input data immutable.
# WARNING: Making input data immutable.
# WARNING: Making input data immutable.
# WARNING: Making input data immutable.
# WARNING: Making input data immutable.
# WARNING: Making input data immutable.
# WARNING: Making input data immutable.
# WARNING: Making input data immutable.
# WARNING: Making input data immutable.
# WARNING: Making input data immutable.
# WARNING: Making input data immutable.
# WARNING: Making input data immutable.
# WARNING: Making input data immutable.
# WARNING: Making input data immutable.
# WARNING: Making input data immutable.
# WARNING: Making input data immutable.
# WARNING: Making input data immutable.
# WARNING: Making input data immutable.
# WARNING: Making input data immutable.
# WARNING: Making input data immutable.
# WARNING: Making input data immutable.
# WARNING: Making input data immutable.
# /Users/oa265351/opt/miniconda3/envs/denoising/lib/python3.9/site-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:374: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# 1/1 [==============================] - 5s 5s/step - loss: 0.1132 - val_loss: 0.1265
# allo
# (51, 51, 10)
#  - Converged!
# 100% (100 of 100) |######################| Elapsed Time: 0:00:00 ETA:  00:00:00
# 100% (200 of 200) |######################| Elapsed Time: 0:02:33 Time:  0:02:33
# allo
# (51, 51, 10)
#  - Converged!
# 100% (100 of 100) |######################| Elapsed Time: 0:00:00 ETA:  00:00:00
#  35% (106 of 300) |#######               | Elapsed Time: 0:00:52 ETA:   0:01:46
#  - Converged!
# 100% (300 of 300) |######################| Elapsed Time: 0:00:53 Time:  0:00:53
#   7% (38 of 500) |#                      | Elapsed Time: 0:00:00 ETA:   0:00:04
#  - Converged!
# 100% (500 of 500) |######################| Elapsed Time: 0:00:00 Time:  0:00:00
#  15% (46 of 300) |###                    | Elapsed Time: 0:00:25 ETA:   0:02:04
#  - Converged!
# 100% (300 of 300) |######################| Elapsed Time: 0:00:25 Time:  0:00:25
#   1% (7 of 500) |                        | Elapsed Time: 0:00:00 ETA:  00:00:00
#  - Converged!
# 100% (500 of 500) |######################| Elapsed Time: 0:00:00 Time:  0:00:00
#  19% (58 of 300) |####                   | Elapsed Time: 0:00:26 ETA:   0:01:55
#  - Converged!
# 100% (300 of 300) |######################| Elapsed Time: 0:00:27 Time:  0:00:27
#   1% (7 of 500) |                        | Elapsed Time: 0:00:00 ETA:  00:00:00
#  - Converged!
# 100% (500 of 500) |######################| Elapsed Time: 0:00:00 Time:  0:00:00
#  12% (38 of 300) |##                     | Elapsed Time: 0:00:17 ETA:   0:01:58
#  - Converged!
# 100% (300 of 300) |######################| Elapsed Time: 0:00:18 Time:  0:00:18
#   3% (19 of 500) |                       | Elapsed Time: 0:00:00 ETA:   0:00:03
#  - Converged!
# 100% (500 of 500) |######################| Elapsed Time: 0:00:00 Time:  0:00:00
#  14% (42 of 300) |###                    | Elapsed Time: 0:00:19 ETA:   0:01:57
#  - Converged!
# 100% (300 of 300) |######################| Elapsed Time: 0:00:19 Time:  0:00:19
#   3% (19 of 500) |                       | Elapsed Time: 0:00:00 ETA:   0:00:03
#  - Converged!
# 100% (500 of 500) |######################| Elapsed Time: 0:00:00 Time:  0:00:00
#  11% (34 of 300) |##                     | Elapsed Time: 0:00:17 ETA:   0:02:19
#  - Converged!
# 100% (300 of 300) |######################| Elapsed Time: 0:00:18 Time:  0:00:18
#   6% (32 of 500) |#                      | Elapsed Time: 0:00:00 ETA:   0:00:04
#  - Converged!
# 100% (500 of 500) |######################| Elapsed Time: 0:00:00 Time:  0:00:00
#  28% (86 of 300) |######                 | Elapsed Time: 0:00:40 ETA:   0:01:39
#  - Converged!
# 100% (300 of 300) |######################| Elapsed Time: 0:00:41 Time:  0:00:41
#   2% (13 of 500) |                       | Elapsed Time: 0:00:00 ETA:  00:00:00
#  - Converged!
# 100% (500 of 500) |######################| Elapsed Time: 0:00:00 Time:  0:00:00
#  23% (70 of 300) |#####                  | Elapsed Time: 0:00:32 ETA:   0:01:45
#  - Converged!
# 100% (300 of 300) |######################| Elapsed Time: 0:00:32 Time:  0:00:32
#   1% (7 of 500) |                        | Elapsed Time: 0:00:00 ETA:  00:00:00
#  - Converged!
# 100% (500 of 500) |######################| Elapsed Time: 0:00:00 Time:  0:00:00
#  20% (62 of 300) |####                   | Elapsed Time: 0:00:28 ETA:   0:01:48
#  - Converged!
# 100% (300 of 300) |######################| Elapsed Time: 0:00:28 Time:  0:00:28
#   6% (32 of 500) |#                      | Elapsed Time: 0:00:00 ETA:   0:00:03
#  - Converged!
# 100% (500 of 500) |######################| Elapsed Time: 0:00:00 Time:  0:00:00
#  24% (74 of 300) |#####                  | Elapsed Time: 0:00:34 ETA:   0:01:46
#  - Converged!
# 100% (300 of 300) |######################| Elapsed Time: 0:00:34 Time:  0:00:34
#   6% (32 of 500) |#                      | Elapsed Time: 0:00:00 ETA:   0:00:03
#  - Converged!
# 100% (500 of 500) |######################| Elapsed Time: 0:00:00 Time:  0:00:00
#  10% (30 of 300) |##                     | Elapsed Time: 0:00:13 ETA:   0:02:03
#  - Converged!
# 100% (300 of 300) |######################| Elapsed Time: 0:00:14 Time:  0:00:14
#   1% (7 of 500) |                        | Elapsed Time: 0:00:00 ETA:  00:00:00
#  - Converged!
# 100% (500 of 500) |######################| Elapsed Time: 0:00:00 Time:  0:00:00
#  15% (46 of 300) |###                    | Elapsed Time: 0:00:21 ETA:   0:01:56
#  - Converged!
# 100% (300 of 300) |######################| Elapsed Time: 0:00:21 Time:  0:00:21
#   9% (45 of 500) |##                     | Elapsed Time: 0:00:00 ETA:   0:00:03
#  - Converged!
# 100% (500 of 500) |######################| Elapsed Time: 0:00:00 Time:  0:00:00
#  26% (78 of 300) |#####                  | Elapsed Time: 0:00:35 ETA:   0:01:41
#  - Converged!
# 100% (300 of 300) |######################| Elapsed Time: 0:00:36 Time:  0:00:36
# N/A% (0 of 500) |                        | Elapsed Time: 0:00:00 ETA:  --:--:--
#  - Converged!
# 100% (500 of 500) |######################| Elapsed Time: 0:00:00 Time:  0:00:00
#  30% (90 of 300) |######                 | Elapsed Time: 0:00:41 ETA:   0:01:36
#  - Converged!
# 100% (300 of 300) |######################| Elapsed Time: 0:00:41 Time:  0:00:41
#   3% (19 of 500) |                       | Elapsed Time: 0:00:00 ETA:   0:00:03
#  - Converged!
# 100% (500 of 500) |######################| Elapsed Time: 0:00:00 Time:  0:00:00
#  18% (54 of 300) |####                   | Elapsed Time: 0:00:24 ETA:   0:01:56
#  - Converged!
# 100% (300 of 300) |######################| Elapsed Time: 0:00:25 Time:  0:00:25
#   7% (38 of 500) |#                      | Elapsed Time: 0:00:00 ETA:   0:00:03
#  - Converged!
# 100% (500 of 500) |######################| Elapsed Time: 0:00:00 Time:  0:00:00
#  23% (70 of 300) |#####                  | Elapsed Time: 0:00:32 ETA:   0:01:44
#  - Converged!
# 100% (300 of 300) |######################| Elapsed Time: 0:00:32 Time:  0:00:32
#   3% (19 of 500) |                       | Elapsed Time: 0:00:00 ETA:   0:00:03
#  - Converged!
# 100% (500 of 500) |######################| Elapsed Time: 0:00:00 Time:  0:00:00
#  11% (34 of 300) |##                     | Elapsed Time: 0:00:15 ETA:   0:02:01
#  - Converged!
# 100% (300 of 300) |######################| Elapsed Time: 0:00:15 Time:  0:00:15
#   5% (26 of 500) |#                      | Elapsed Time: 0:00:00 ETA:   0:00:03
#  - Converged!
# 100% (500 of 500) |######################| Elapsed Time: 0:00:00 Time:  0:00:00
#  19% (58 of 300) |####                   | Elapsed Time: 0:00:26 ETA:   0:01:51
#  - Converged!
# 100% (300 of 300) |######################| Elapsed Time: 0:00:27 Time:  0:00:27
#   1% (7 of 500) |                        | Elapsed Time: 0:00:00 ETA:  00:00:00
#  - Converged!
# 100% (500 of 500) |######################| Elapsed Time: 0:00:00 Time:  0:00:00
#  14% (42 of 300) |###                    | Elapsed Time: 0:00:19 ETA:   0:01:58
#  - Converged!
# 100% (300 of 300) |######################| Elapsed Time: 0:00:19 Time:  0:00:19
# N/A% (0 of 500) |                        | Elapsed Time: 0:00:00 ETA:  --:--:--
#  - Converged!
# 100% (500 of 500) |######################| Elapsed Time: 0:00:00 Time:  0:00:00
#  20% (62 of 300) |####                   | Elapsed Time: 0:00:28 ETA:   0:01:47
#  - Converged!
# 100% (300 of 300) |######################| Elapsed Time: 0:00:28 Time:  0:00:28
#   3% (19 of 500) |                       | Elapsed Time: 0:00:00 ETA:   0:00:03
#  - Converged!
# 100% (500 of 500) |######################| Elapsed Time: 0:00:00 Time:  0:00:00
#  16% (50 of 300) |###                    | Elapsed Time: 0:00:23 ETA:   0:01:54
#  - Converged!
# 100% (300 of 300) |######################| Elapsed Time: 0:00:23 Time:  0:00:23
#   3% (19 of 500) |                       | Elapsed Time: 0:00:00 ETA:   0:00:03
#  - Converged!
# 100% (500 of 500) |######################| Elapsed Time: 0:00:00 Time:  0:00:00
#  18% (54 of 300) |####                   | Elapsed Time: 0:00:24 ETA:   0:01:53
#  - Converged!
# 100% (300 of 300) |######################| Elapsed Time: 0:00:25 Time:  0:00:25
#   3% (19 of 500) |                       | Elapsed Time: 0:00:00 ETA:   0:00:03
#  - Converged!
# 100% (500 of 500) |######################| Elapsed Time: 0:00:00 Time:  0:00:00
#  15% (46 of 300) |###                    | Elapsed Time: 0:00:21 ETA:   0:01:57
#  - Converged!
# 100% (300 of 300) |######################| Elapsed Time: 0:00:21 Time:  0:00:21
#   5% (26 of 500) |#                      | Elapsed Time: 0:00:00 ETA:   0:00:03
#  - Converged!
# 100% (500 of 500) |######################| Elapsed Time: 0:00:00 Time:  0:00:00
#  19% (58 of 300) |####                   | Elapsed Time: 0:00:27 ETA:   0:01:49
#  - Converged!
# 100% (300 of 300) |######################| Elapsed Time: 0:00:27 Time:  0:00:27
#   6% (32 of 500) |#                      | Elapsed Time: 0:00:00 ETA:   0:00:03
#  - Converged!
# 100% (500 of 500) |######################| Elapsed Time: 0:00:00 Time:  0:00:00
#  24% (74 of 300) |#####                  | Elapsed Time: 0:00:33 ETA:   0:01:41
#  - Converged!
# 100% (300 of 300) |######################| Elapsed Time: 0:00:34 Time:  0:00:34
#   6% (32 of 500) |#                      | Elapsed Time: 0:00:00 ETA:   0:00:03
#  - Converged!
# 100% (500 of 500) |######################| Elapsed Time: 0:00:00 Time:  0:00:00
#  15% (46 of 300) |###                    | Elapsed Time: 0:00:21 ETA:   0:01:57
#  - Converged!
# 100% (300 of 300) |######################| Elapsed Time: 0:00:21 Time:  0:00:21
#   3% (19 of 500) |                       | Elapsed Time: 0:00:00 ETA:   0:00:03
#  - Converged!
# 100% (500 of 500) |######################| Elapsed Time: 0:00:00 Time:  0:00:00
#  10% (30 of 300) |##                     | Elapsed Time: 0:00:13 ETA:   0:02:02
#  - Converged!
# 100% (300 of 300) |######################| Elapsed Time: 0:00:14 Time:  0:00:14
#   7% (38 of 500) |#                      | Elapsed Time: 0:00:00 ETA:   0:00:03
#  - Converged!
# 100% (500 of 500) |######################| Elapsed Time: 0:00:00 Time:  0:00:00
#  35% (106 of 300) |#######               | Elapsed Time: 0:00:48 ETA:   0:01:29
#  - Converged!
# 100% (300 of 300) |######################| Elapsed Time: 0:00:49 Time:  0:00:49
#   3% (19 of 500) |                       | Elapsed Time: 0:00:00 ETA:   0:00:03
#  - Converged!
# 100% (500 of 500) |######################| Elapsed Time: 0:00:00 Time:  0:00:00
#  20% (62 of 300) |####                   | Elapsed Time: 0:00:33 ETA:   0:02:07
#  - Converged!
# 100% (300 of 300) |######################| Elapsed Time: 0:00:33 Time:  0:00:33
#   5% (26 of 500) |#                      | Elapsed Time: 0:00:00 ETA:   0:00:03
#  - Converged!
# 100% (500 of 500) |######################| Elapsed Time: 0:00:00 Time:  0:00:00
#  24% (74 of 300) |#####                  | Elapsed Time: 0:00:34 ETA:   0:01:43
#  - Converged!
# 100% (300 of 300) |######################| Elapsed Time: 0:00:35 Time:  0:00:35
# N/A% (0 of 500) |                        | Elapsed Time: 0:00:00 ETA:  --:--:--
#  - Converged!
# 100% (500 of 500) |######################| Elapsed Time: 0:00:00 Time:  0:00:00
#  12% (38 of 300) |##                     | Elapsed Time: 0:00:17 ETA:   0:01:59
#  - Converged!
# 100% (300 of 300) |######################| Elapsed Time: 0:00:18 Time:  0:00:18
#   3% (19 of 500) |                       | Elapsed Time: 0:00:00 ETA:   0:00:03
#  - Converged!
# 100% (500 of 500) |######################| Elapsed Time: 0:00:00 Time:  0:00:00
#  12% (38 of 300) |##                     | Elapsed Time: 0:00:17 ETA:   0:01:58
#  - Converged!
# 100% (300 of 300) |######################| Elapsed Time: 0:00:17 Time:  0:00:17
#   3% (19 of 500) |                       | Elapsed Time: 0:00:00 ETA:   0:00:03
#  - Converged!
# 100% (500 of 500) |######################| Elapsed Time: 0:00:00 Time:  0:00:00
#  15% (46 of 300) |###                    | Elapsed Time: 0:00:21 ETA:   0:01:55
#  - Converged!
# 100% (300 of 300) |######################| Elapsed Time: 0:00:21 Time:  0:00:21
#   6% (32 of 500) |#                      | Elapsed Time: 0:00:00 ETA:   0:00:03
#  - Converged!
# 100% (500 of 500) |######################| Elapsed Time: 0:00:00 Time:  0:00:00
#  15% (46 of 300) |###                    | Elapsed Time: 0:00:21 ETA:   0:01:55
#  - Converged!
# 100% (300 of 300) |######################| Elapsed Time: 0:00:21 Time:  0:00:21
#   1% (7 of 500) |                        | Elapsed Time: 0:00:00 ETA:  00:00:00
#  - Converged!
# 100% (500 of 500) |######################| Elapsed Time: 0:00:00 Time:  0:00:00
#  27% (82 of 300) |######                 | Elapsed Time: 0:00:38 ETA:   0:01:46
#  - Converged!
# 100% (300 of 300) |######################| Elapsed Time: 0:00:38 Time:  0:00:38
#   6% (32 of 500) |#                      | Elapsed Time: 0:00:00 ETA:   0:00:03
#  - Converged!
# 100% (500 of 500) |######################| Elapsed Time: 0:00:00 Time:  0:00:00
#  27% (82 of 300) |######                 | Elapsed Time: 0:00:38 ETA:   0:01:40
#  - Converged!
# 100% (300 of 300) |######################| Elapsed Time: 0:00:38 Time:  0:00:38
#   6% (32 of 500) |#                      | Elapsed Time: 0:00:00 ETA:   0:00:03
#  - Converged!
# 100% (500 of 500) |######################| Elapsed Time: 0:00:00 Time:  0:00:00
#  12% (38 of 300) |##                     | Elapsed Time: 0:00:17 ETA:   0:02:00
#  - Converged!
# 100% (300 of 300) |######################| Elapsed Time: 0:00:17 Time:  0:00:17
#   6% (32 of 500) |#                      | Elapsed Time: 0:00:00 ETA:   0:00:03
#  - Converged!
# 100% (500 of 500) |######################| Elapsed Time: 0:00:00 Time:  0:00:00
#  20% (62 of 300) |####                   | Elapsed Time: 0:00:28 ETA:   0:01:48
#  - Converged!
# 100% (300 of 300) |######################| Elapsed Time: 0:00:29 Time:  0:00:29
#   5% (26 of 500) |#                      | Elapsed Time: 0:00:00 ETA:   0:00:03
#  - Converged!
# 100% (500 of 500) |######################| Elapsed Time: 0:00:00 Time:  0:00:00
#  15% (46 of 300) |###                    | Elapsed Time: 0:00:21 ETA:   0:01:56
#  - Converged!
# 100% (300 of 300) |######################| Elapsed Time: 0:00:21 Time:  0:00:21
# N/A% (0 of 500) |                        | Elapsed Time: 0:00:00 ETA:  --:--:--
#  - Converged!
# 100% (500 of 500) |######################| Elapsed Time: 0:00:00 Time:  0:00:00
#  12% (38 of 300) |##                     | Elapsed Time: 0:00:17 ETA:   0:02:00
#  - Converged!
# 100% (300 of 300) |######################| Elapsed Time: 0:00:18 Time:  0:00:18
#   3% (19 of 500) |                       | Elapsed Time: 0:00:00 ETA:   0:00:03
#  - Converged!
# 100% (500 of 500) |######################| Elapsed Time: 0:00:00 Time:  0:00:00
#   2% (6 of 300) |                        | Elapsed Time: 0:00:02 ETA:   0:02:17
#  - Converged!
# 100% (300 of 300) |######################| Elapsed Time: 0:00:03 Time:  0:00:03
#   2% (6 of 300) |                        | Elapsed Time: 0:00:03 ETA:   0:02:56
#  - Converged!
# 100% (300 of 300) |######################| Elapsed Time: 0:00:03 Time:  0:00:03
#   2% (6 of 300) |                        | Elapsed Time: 0:00:03 ETA:   0:02:37
#  - Converged!
# 100% (300 of 300) |######################| Elapsed Time: 0:00:03 Time:  0:00:03
#   2% (6 of 300) |                        | Elapsed Time: 0:00:02 ETA:   0:02:16
#  - Converged!
# 100% (300 of 300) |######################| Elapsed Time: 0:00:03 Time:  0:00:03
#   2% (6 of 300) |                        | Elapsed Time: 0:00:02 ETA:   0:02:16
#  - Converged!
# 100% (300 of 300) |######################| Elapsed Time: 0:00:03 Time:  0:00:03
#   2% (6 of 300) |                        | Elapsed Time: 0:00:02 ETA:   0:02:15
#  - Converged!
# 100% (300 of 300) |######################| Elapsed Time: 0:00:03 Time:  0:00:03
#   2% (6 of 300) |                        | Elapsed Time: 0:00:02 ETA:   0:02:18
#  - Converged!
# 100% (300 of 300) |######################| Elapsed Time: 0:00:03 Time:  0:00:03
#   2% (6 of 300) |                        | Elapsed Time: 0:00:02 ETA:   0:02:16
#  - Converged!
# 100% (300 of 300) |######################| Elapsed Time: 0:00:03 Time:  0:00:03
#   2% (6 of 300) |                        | Elapsed Time: 0:00:02 ETA:   0:02:17
#  - Converged!
# 100% (300 of 300) |######################| Elapsed Time: 0:00:03 Time:  0:00:03
#   3% (10 of 300) |                       | Elapsed Time: 0:00:04 ETA:   0:02:14
#  - Converged!
# 100% (300 of 300) |######################| Elapsed Time: 0:00:05 Time:  0:00:05
#   0% (2 of 300) |                        | Elapsed Time: 0:00:00 ETA:   0:02:17
#  - Converged!
# 100% (300 of 300) |######################| Elapsed Time: 0:00:01 Time:  0:00:01
#   2% (6 of 300) |                        | Elapsed Time: 0:00:02 ETA:   0:02:15
#  - Converged!
# 100% (300 of 300) |######################| Elapsed Time: 0:00:03 Time:  0:00:03
#   2% (6 of 300) |                        | Elapsed Time: 0:00:02 ETA:   0:02:16
#  - Converged!
# 100% (300 of 300) |######################| Elapsed Time: 0:00:03 Time:  0:00:03
#   2% (6 of 300) |                        | Elapsed Time: 0:00:02 ETA:   0:02:17
#  - Converged!
# 100% (300 of 300) |######################| Elapsed Time: 0:00:03 Time:  0:00:03
#   2% (6 of 300) |                        | Elapsed Time: 0:00:02 ETA:   0:02:17
#  - Converged!
# 100% (300 of 300) |######################| Elapsed Time: 0:00:03 Time:  0:00:03
#   2% (6 of 300) |                        | Elapsed Time: 0:00:02 ETA:   0:02:16
#  - Converged!
# 100% (300 of 300) |######################| Elapsed Time: 0:00:03 Time:  0:00:03
#   2% (6 of 300) |                        | Elapsed Time: 0:00:02 ETA:   0:02:26
#  - Converged!
# 100% (300 of 300) |######################| Elapsed Time: 0:00:03 Time:  0:00:03
#   2% (6 of 300) |                        | Elapsed Time: 0:00:02 ETA:   0:02:16
#  - Converged!
# 100% (300 of 300) |######################| Elapsed Time: 0:00:03 Time:  0:00:03
#   2% (6 of 300) |                        | Elapsed Time: 0:00:02 ETA:   0:02:17
#  - Converged!
# 100% (300 of 300) |######################| Elapsed Time: 0:00:03 Time:  0:00:03
#   2% (6 of 300) |                        | Elapsed Time: 0:00:02 ETA:   0:02:21
#  - Converged!
# 100% (300 of 300) |######################| Elapsed Time: 0:00:03 Time:  0:00:03
#   2% (6 of 300) |                        | Elapsed Time: 0:00:02 ETA:   0:02:16
#  - Converged!
# 100% (300 of 300) |######################| Elapsed Time: 0:00:03 Time:  0:00:03
#   2% (6 of 300) |                        | Elapsed Time: 0:00:02 ETA:   0:02:16
#  - Converged!
# 100% (300 of 300) |######################| Elapsed Time: 0:00:03 Time:  0:00:03
#   2% (6 of 300) |                        | Elapsed Time: 0:00:02 ETA:   0:02:16
#  - Converged!
# 100% (300 of 300) |######################| Elapsed Time: 0:00:03 Time:  0:00:03
#   2% (6 of 300) |                        | Elapsed Time: 0:00:02 ETA:   0:02:16
#  - Converged!
# 100% (300 of 300) |######################| Elapsed Time: 0:00:03 Time:  0:00:03
#   2% (6 of 300) |                        | Elapsed Time: 0:00:03 ETA:   0:02:31
#  - Converged!
# 100% (300 of 300) |######################| Elapsed Time: 0:00:03 Time:  0:00:03
#   2% (6 of 300) |                        | Elapsed Time: 0:00:02 ETA:   0:02:16
#  - Converged!
# 100% (300 of 300) |######################| Elapsed Time: 0:00:03 Time:  0:00:03
#   2% (6 of 300) |                        | Elapsed Time: 0:00:02 ETA:   0:02:16
#  - Converged!
# 100% (300 of 300) |######################| Elapsed Time: 0:00:03 Time:  0:00:03
#   2% (6 of 300) |                        | Elapsed Time: 0:00:02 ETA:   0:02:16
#  - Converged!
# 100% (300 of 300) |######################| Elapsed Time: 0:00:03 Time:  0:00:03
#   2% (6 of 300) |                        | Elapsed Time: 0:00:02 ETA:   0:02:16
#  - Converged!
# 100% (300 of 300) |######################| Elapsed Time: 0:00:03 Time:  0:00:03
#   2% (6 of 300) |                        | Elapsed Time: 0:00:02 ETA:   0:02:16
#  - Converged!
# 100% (300 of 300) |######################| Elapsed Time: 0:00:03 Time:  0:00:03
#   2% (6 of 300) |                        | Elapsed Time: 0:00:02 ETA:   0:02:15
#  - Converged!
# 100% (300 of 300) |######################| Elapsed Time: 0:00:03 Time:  0:00:03
#   4% (14 of 300) |#                      | Elapsed Time: 0:00:06 ETA:   0:02:12
#  - Converged!
# 100% (300 of 300) |######################| Elapsed Time: 0:00:06 Time:  0:00:06
#   2% (6 of 300) |                        | Elapsed Time: 0:00:02 ETA:   0:02:16
#  - Converged!
# 100% (300 of 300) |######################| Elapsed Time: 0:00:03 Time:  0:00:03
#   2% (6 of 300) |                        | Elapsed Time: 0:00:02 ETA:   0:02:17
#  - Converged!
# 100% (300 of 300) |######################| Elapsed Time: 0:00:03 Time:  0:00:03
#   2% (6 of 300) |                        | Elapsed Time: 0:00:02 ETA:   0:02:16
#  - Converged!
# 100% (300 of 300) |######################| Elapsed Time: 0:00:03 Time:  0:00:03
#   2% (6 of 300) |                        | Elapsed Time: 0:00:02 ETA:   0:02:20
#  - Converged!
# 100% (300 of 300) |######################| Elapsed Time: 0:00:03 Time:  0:00:03
#   2% (6 of 300) |                        | Elapsed Time: 0:00:02 ETA:   0:02:15
#  - Converged!
# 100% (300 of 300) |######################| Elapsed Time: 0:00:03 Time:  0:00:03
#   2% (6 of 300) |                        | Elapsed Time: 0:00:02 ETA:   0:02:14
#  - Converged!
# 100% (300 of 300) |######################| Elapsed Time: 0:00:03 Time:  0:00:03
#   2% (6 of 300) |                        | Elapsed Time: 0:00:02 ETA:   0:02:15
#  - Converged!
# 100% (300 of 300) |######################| Elapsed Time: 0:00:03 Time:  0:00:03
#   2% (6 of 300) |                        | Elapsed Time: 0:00:02 ETA:   0:02:24
#  - Converged!
# 100% (300 of 300) |######################| Elapsed Time: 0:00:03 Time:  0:00:03

# %% [markdown]
# # Validation

# %% [raw]
# fitted_model_path = './../data/mccd_inputs/fitted_model2086592.npy'
# test_cat_path = './../data/mccd_inputs/test_star_selection-2086592.fits'

# %%
# Import
test_cat = fits.open(test_cat_path)[1]
val_dict = mccd_aux.mccd_validation(fitted_model_path, test_cat)

# %%
val_dict.keys()
# Out:
# dict_keys(['PSF_VIGNET_LIST', 'PSF_MOM_LIST', 'STAR_MOM_LIST', 'GLOB_POSITION_IMG_LIST', 'VIGNET_LIST', 'MASK_LIST', 'CCD_ID_LIST'])

# %%
test_stars = val_dict['VIGNET_LIST']
matched_PSFs = val_dict['PSF_VIGNET_LIST']

e1_psf = val_dict['PSF_MOM_LIST'][:,0]
e2_psf = val_dict['PSF_MOM_LIST'][:,1]
R2_psf = 2.*val_dict['PSF_MOM_LIST'][:,2]**2

e1_star = val_dict['STAR_MOM_LIST'][:,0]
e2_star = val_dict['STAR_MOM_LIST'][:,1]
R2_star = 2.*val_dict['STAR_MOM_LIST'][:,2]**2

# %%
pix_RMSE = np.sqrt(np.mean((test_stars - matched_PSFs)**2))
e1_RMSE = np.sqrt(np.mean((e1_star - e1_psf)**2))
e2_RMSE = np.sqrt(np.mean((e2_star - e2_psf)**2))
R2_RMSE = np.sqrt(np.mean(((R2_star - R2_psf)/R2_star)**2))

print('Pixel RMSE = %.5e'%(pix_RMSE))
print('e1 RMSE = %.5e'%(e1_RMSE))
print('e2 RMSE = %.5e'%(e2_RMSE))
print('R2 RMSE = %.5e'%(R2_RMSE))
# Out:
# Pixel RMSE = 2.64408e-04
# e1 RMSE = 2.38796e-02
# e2 RMSE = 2.75909e-02
# R2 RMSE = 3.97102e-02

# %% [markdown]
# ## Plot a random test star and its model reconstruction

# %%
idx = random.randint(0,test_stars.shape[0])

plot_fun(test_stars[idx,:,:])
plot_fun(matched_PSFs[idx,:,:])
plot_fun(test_stars[idx,:,:] - matched_PSFs[idx,:,:])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~/opt/miniconda3/envs/denoising/lib/python3.9/site-packages/matplotlib/texmanager.py in _run_checked_subprocess(self, command, tex)
#     274         try:
# --> 275             report = subprocess.check_output(command,
#     276                                              cwd=self.texcache,
#
# ~/opt/miniconda3/envs/denoising/lib/python3.9/subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     423
# --> 424     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#     425                **kwargs).stdout
#
# ~/opt/miniconda3/envs/denoising/lib/python3.9/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     504
# --> 505     with Popen(*popenargs, **kwargs) as process:
#     506         try:
#
# ~/opt/miniconda3/envs/denoising/lib/python3.9/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask)
#     950
# --> 951             self._execute_child(args, executable, preexec_fn, close_fds,
#     952                                 pass_fds, cwd, env,
#
# ~/opt/miniconda3/envs/denoising/lib/python3.9/subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, gid, gids, uid, umask, start_new_session)
#    1822                         err_msg = os.strerror(errno_num)
# -> 1823                     raise child_exception_type(errno_num, err_msg, err_filename)
#    1824                 raise child_exception_type(err_msg)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'latex'
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-18-847b62767851> in <module>
#       1 idx = random.randint(0,test_stars.shape[0])
#       2
# ----> 3 plot_fun(test_stars[idx,:,:])
#       4 plot_fun(matched_PSFs[idx,:,:])
#       5 plot_fun(test_stars[idx,:,:] - matched_PSFs[idx,:,:])
#
# <ipython-input-2-387e73bc35f1> in plot_fun(star_img, cmap)
#      29     cbar = fig.colorbar(im1, cax=cax, extend='both')
#      30     cbar.minorticks_on()
# ---> 31     fig.tight_layout()
#      32     ax1.set_xticks([]);ax1.set_yticks([])
#      33     ax1.axis('off')
#
# ~/opt/miniconda3/envs/denoising/lib/python3.9/site-packages/matplotlib/cbook/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     409                          else deprecation_addendum,
#     410                 **kwargs)
# --> 411         return func(*inner_args, **inner_kwargs)
#     412
#     413     return wrapper
#
# ~/opt/miniconda3/envs/denoising/lib/python3.9/site-packages/matplotlib/figure.py in tight_layout(self, renderer, pad, h_pad, w_pad, rect)
#    2611                else suppress())
#    2612         with ctx:
# -> 2613             kwargs = get_tight_layout_figure(
#    2614                 self, self.axes, subplotspec_list, renderer,
#    2615                 pad=pad, h_pad=h_pad, w_pad=w_pad, rect=rect)
#
# ~/opt/miniconda3/envs/denoising/lib/python3.9/site-packages/matplotlib/tight_layout.py in get_tight_layout_figure(fig, axes_list, subplotspec_list, renderer, pad, h_pad, w_pad, rect)
#     301                               (colNum2 + 1) * div_col - 1))
#     302
# --> 303     kwargs = auto_adjust_subplotpars(fig, renderer,
#     304                                      nrows_ncols=(max_nrows, max_ncols),
#     305                                      num1num2_list=num1num2_list,
#
# ~/opt/miniconda3/envs/denoising/lib/python3.9/site-packages/matplotlib/tight_layout.py in auto_adjust_subplotpars(fig, renderer, nrows_ncols, num1num2_list, subplot_list, ax_bbox_list, pad, h_pad, w_pad, rect)
#      82             if ax.get_visible():
#      83                 try:
# ---> 84                     bb += [ax.get_tightbbox(renderer, for_layout_only=True)]
#      85                 except TypeError:
#      86                     bb += [ax.get_tightbbox(renderer)]
#
# ~/opt/miniconda3/envs/denoising/lib/python3.9/site-packages/matplotlib/axes/_base.py in get_tightbbox(self, renderer, call_axes_locator, bbox_extra_artists, for_layout_only)
#    4151             if self.xaxis.get_visible():
#    4152                 try:
# -> 4153                     bb_xaxis = self.xaxis.get_tightbbox(
#    4154                         renderer, for_layout_only=for_layout_only)
#    4155                 except TypeError:
#
# ~/opt/miniconda3/envs/denoising/lib/python3.9/site-packages/matplotlib/axis.py in get_tightbbox(self, renderer, for_layout_only)
#    1109         ticks_to_draw = self._update_ticks()
#    1110
# -> 1111         self._update_label_position(renderer)
#    1112
#    1113         # go back to just this axis's tick labels
#
# ~/opt/miniconda3/envs/denoising/lib/python3.9/site-packages/matplotlib/axis.py in _update_label_position(self, renderer)
#    2059         # get bounding boxes for this axis and any siblings
#    2060         # that have been set by `fig.align_xlabels()`
# -> 2061         bboxes, bboxes2 = self._get_tick_boxes_siblings(renderer=renderer)
#    2062
#    2063         x, y = self.label.get_position()
#
# ~/opt/miniconda3/envs/denoising/lib/python3.9/site-packages/matplotlib/axis.py in _get_tick_boxes_siblings(self, renderer)
#    2044         for nn, axx in enumerate(grp.get_siblings(self.axes)):
#    2045             ticks_to_draw = axx.xaxis._update_ticks()
# -> 2046             tlb, tlb2 = axx.xaxis._get_tick_bboxes(ticks_to_draw, renderer)
#    2047             bboxes.extend(tlb)
#    2048             bboxes2.extend(tlb2)
#
# ~/opt/miniconda3/envs/denoising/lib/python3.9/site-packages/matplotlib/axis.py in _get_tick_bboxes(self, ticks, renderer)
#    1089     def _get_tick_bboxes(self, ticks, renderer):
#    1090         """Return lists of bboxes for ticks' label1's and label2's."""
# -> 1091         return ([tick.label1.get_window_extent(renderer)
#    1092                  for tick in ticks if tick.label1.get_visible()],
#    1093                 [tick.label2.get_window_extent(renderer)
#
# ~/opt/miniconda3/envs/denoising/lib/python3.9/site-packages/matplotlib/axis.py in <listcomp>(.0)
#    1089     def _get_tick_bboxes(self, ticks, renderer):
#    1090         """Return lists of bboxes for ticks' label1's and label2's."""
# -> 1091         return ([tick.label1.get_window_extent(renderer)
#    1092                  for tick in ticks if tick.label1.get_visible()],
#    1093                 [tick.label2.get_window_extent(renderer)
#
# ~/opt/miniconda3/envs/denoising/lib/python3.9/site-packages/matplotlib/text.py in get_window_extent(self, renderer, dpi)
#     900
#     901         with cbook._setattr_cm(self.figure, dpi=dpi):
# --> 902             bbox, info, descent = self._get_layout(self._renderer)
#     903             x, y = self.get_unitless_position()
#     904             x, y = self.get_transform().transform((x, y))
#
# ~/opt/miniconda3/envs/denoising/lib/python3.9/site-packages/matplotlib/text.py in _get_layout(self, renderer)
#     285
#     286         # Full vertical extent of font, including ascenders and descenders:
# --> 287         _, lp_h, lp_d = renderer.get_text_width_height_descent(
#     288             "lp", self._fontproperties,
#     289             ismath="TeX" if self.get_usetex() else False)
#
# ~/opt/miniconda3/envs/denoising/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py in get_text_width_height_descent(self, s, prop, ismath)
#     225             texmanager = self.get_texmanager()
#     226             fontsize = prop.get_size_in_points()
# --> 227             w, h, d = texmanager.get_text_width_height_descent(
#     228                 s, fontsize, renderer=self)
#     229             return w, h, d
#
# ~/opt/miniconda3/envs/denoising/lib/python3.9/site-packages/matplotlib/texmanager.py in get_text_width_height_descent(self, tex, fontsize, renderer)
#     421         else:
#     422             # use dviread.
# --> 423             dvifile = self.make_dvi(tex, fontsize)
#     424             with dviread.Dvi(dvifile, 72 * dpi_fraction) as dvi:
#     425                 page, = dvi
#
# ~/opt/miniconda3/envs/denoising/lib/python3.9/site-packages/matplotlib/texmanager.py in make_dvi(self, tex, fontsize)
#     307             texfile = self.make_tex(tex, fontsize)
#     308             with cbook._lock_path(texfile):
# --> 309                 self._run_checked_subprocess(
#     310                     ["latex", "-interaction=nonstopmode", "--halt-on-error",
#     311                      texfile], tex)
#
# ~/opt/miniconda3/envs/denoising/lib/python3.9/site-packages/matplotlib/texmanager.py in _run_checked_subprocess(self, command, tex)
#     277                                              stderr=subprocess.STDOUT)
#     278         except FileNotFoundError as exc:
# --> 279             raise RuntimeError(
#     280                 'Failed to process string with tex because {} could not be '
#     281                 'found'.format(command[0])) from exc
#
# RuntimeError: Failed to process string with tex because latex could not be found
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~/opt/miniconda3/envs/denoising/lib/python3.9/site-packages/matplotlib/texmanager.py in _run_checked_subprocess(self, command, tex)
#     274         try:
# --> 275             report = subprocess.check_output(command,
#     276                                              cwd=self.texcache,
#
# ~/opt/miniconda3/envs/denoising/lib/python3.9/subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     423
# --> 424     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#     425                **kwargs).stdout
#
# ~/opt/miniconda3/envs/denoising/lib/python3.9/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     504
# --> 505     with Popen(*popenargs, **kwargs) as process:
#     506         try:
#
# ~/opt/miniconda3/envs/denoising/lib/python3.9/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask)
#     950
# --> 951             self._execute_child(args, executable, preexec_fn, close_fds,
#     952                                 pass_fds, cwd, env,
#
# ~/opt/miniconda3/envs/denoising/lib/python3.9/subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, gid, gids, uid, umask, start_new_session)
#    1822                         err_msg = os.strerror(errno_num)
# -> 1823                     raise child_exception_type(errno_num, err_msg, err_filename)
#    1824                 raise child_exception_type(err_msg)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'latex'
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# ~/opt/miniconda3/envs/denoising/lib/python3.9/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/opt/miniconda3/envs/denoising/lib/python3.9/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~/opt/miniconda3/envs/denoising/lib/python3.9/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     130         FigureCanvasBase(fig)
#     131
# --> 132     fig.canvas.print_figure(bytes_io, **kw)
#     133     data = bytes_io.getvalue()
#     134     if fmt == 'svg':
#
# ~/opt/miniconda3/envs/denoising/lib/python3.9/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2191                            else suppress())
#    2192                     with ctx:
# -> 2193                         self.figure.draw(renderer)
#    2194
#    2195                     bbox_inches = self.figure.get_tightbbox(
#
# ~/opt/miniconda3/envs/denoising/lib/python3.9/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# ~/opt/miniconda3/envs/denoising/lib/python3.9/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1855             if self.get_tight_layout() and self.axes:
#    1856                 try:
# -> 1857                     self.tight_layout(**self._tight_parameters)
#    1858                 except ValueError:
#    1859                     pass
#
# ~/opt/miniconda3/envs/denoising/lib/python3.9/site-packages/matplotlib/cbook/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     409                          else deprecation_addendum,
#     410                 **kwargs)
# --> 411         return func(*inner_args, **inner_kwargs)
#     412
#     413     return wrapper
#
# ~/opt/miniconda3/envs/denoising/lib/python3.9/site-packages/matplotlib/figure.py in tight_layout(self, renderer, pad, h_pad, w_pad, rect)
#    2611                else suppress())
#    2612         with ctx:
# -> 2613             kwargs = get_tight_layout_figure(
#    2614                 self, self.axes, subplotspec_list, renderer,
#    2615                 pad=pad, h_pad=h_pad, w_pad=w_pad, rect=rect)
#
# ~/opt/miniconda3/envs/denoising/lib/python3.9/site-packages/matplotlib/tight_layout.py in get_tight_layout_figure(fig, axes_list, subplotspec_list, renderer, pad, h_pad, w_pad, rect)
#     301                               (colNum2 + 1) * div_col - 1))
#     302
# --> 303     kwargs = auto_adjust_subplotpars(fig, renderer,
#     304                                      nrows_ncols=(max_nrows, max_ncols),
#     305                                      num1num2_list=num1num2_list,
#
# ~/opt/miniconda3/envs/denoising/lib/python3.9/site-packages/matplotlib/tight_layout.py in auto_adjust_subplotpars(fig, renderer, nrows_ncols, num1num2_list, subplot_list, ax_bbox_list, pad, h_pad, w_pad, rect)
#      82             if ax.get_visible():
#      83                 try:
# ---> 84                     bb += [ax.get_tightbbox(renderer, for_layout_only=True)]
#      85                 except TypeError:
#      86                     bb += [ax.get_tightbbox(renderer)]
#
# ~/opt/miniconda3/envs/denoising/lib/python3.9/site-packages/matplotlib/axes/_base.py in get_tightbbox(self, renderer, call_axes_locator, bbox_extra_artists, for_layout_only)
#    4151             if self.xaxis.get_visible():
#    4152                 try:
# -> 4153                     bb_xaxis = self.xaxis.get_tightbbox(
#    4154                         renderer, for_layout_only=for_layout_only)
#    4155                 except TypeError:
#
# ~/opt/miniconda3/envs/denoising/lib/python3.9/site-packages/matplotlib/axis.py in get_tightbbox(self, renderer, for_layout_only)
#    1109         ticks_to_draw = self._update_ticks()
#    1110
# -> 1111         self._update_label_position(renderer)
#    1112
#    1113         # go back to just this axis's tick labels
#
# ~/opt/miniconda3/envs/denoising/lib/python3.9/site-packages/matplotlib/axis.py in _update_label_position(self, renderer)
#    2059         # get bounding boxes for this axis and any siblings
#    2060         # that have been set by `fig.align_xlabels()`
# -> 2061         bboxes, bboxes2 = self._get_tick_boxes_siblings(renderer=renderer)
#    2062
#    2063         x, y = self.label.get_position()
#
# ~/opt/miniconda3/envs/denoising/lib/python3.9/site-packages/matplotlib/axis.py in _get_tick_boxes_siblings(self, renderer)
#    2044         for nn, axx in enumerate(grp.get_siblings(self.axes)):
#    2045             ticks_to_draw = axx.xaxis._update_ticks()
# -> 2046             tlb, tlb2 = axx.xaxis._get_tick_bboxes(ticks_to_draw, renderer)
#    2047             bboxes.extend(tlb)
#    2048             bboxes2.extend(tlb2)
#
# ~/opt/miniconda3/envs/denoising/lib/python3.9/site-packages/matplotlib/axis.py in _get_tick_bboxes(self, ticks, renderer)
#    1089     def _get_tick_bboxes(self, ticks, renderer):
#    1090         """Return lists of bboxes for ticks' label1's and label2's."""
# -> 1091         return ([tick.label1.get_window_extent(renderer)
#    1092                  for tick in ticks if tick.label1.get_visible()],
#    1093                 [tick.label2.get_window_extent(renderer)
#
# ~/opt/miniconda3/envs/denoising/lib/python3.9/site-packages/matplotlib/axis.py in <listcomp>(.0)
#    1089     def _get_tick_bboxes(self, ticks, renderer):
#    1090         """Return lists of bboxes for ticks' label1's and label2's."""
# -> 1091         return ([tick.label1.get_window_extent(renderer)
#    1092                  for tick in ticks if tick.label1.get_visible()],
#    1093                 [tick.label2.get_window_extent(renderer)
#
# ~/opt/miniconda3/envs/denoising/lib/python3.9/site-packages/matplotlib/text.py in get_window_extent(self, renderer, dpi)
#     900
#     901         with cbook._setattr_cm(self.figure, dpi=dpi):
# --> 902             bbox, info, descent = self._get_layout(self._renderer)
#     903             x, y = self.get_unitless_position()
#     904             x, y = self.get_transform().transform((x, y))
#
# ~/opt/miniconda3/envs/denoising/lib/python3.9/site-packages/matplotlib/text.py in _get_layout(self, renderer)
#     285
#     286         # Full vertical extent of font, including ascenders and descenders:
# --> 287         _, lp_h, lp_d = renderer.get_text_width_height_descent(
#     288             "lp", self._fontproperties,
#     289             ismath="TeX" if self.get_usetex() else False)
#
# ~/opt/miniconda3/envs/denoising/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py in get_text_width_height_descent(self, s, prop, ismath)
#     225             texmanager = self.get_texmanager()
#     226             fontsize = prop.get_size_in_points()
# --> 227             w, h, d = texmanager.get_text_width_height_descent(
#     228                 s, fontsize, renderer=self)
#     229             return w, h, d
#
# ~/opt/miniconda3/envs/denoising/lib/python3.9/site-packages/matplotlib/texmanager.py in get_text_width_height_descent(self, tex, fontsize, renderer)
#     421         else:
#     422             # use dviread.
# --> 423             dvifile = self.make_dvi(tex, fontsize)
#     424             with dviread.Dvi(dvifile, 72 * dpi_fraction) as dvi:
#     425                 page, = dvi
#
# ~/opt/miniconda3/envs/denoising/lib/python3.9/site-packages/matplotlib/texmanager.py in make_dvi(self, tex, fontsize)
#     307             texfile = self.make_tex(tex, fontsize)
#     308             with cbook._lock_path(texfile):
# --> 309                 self._run_checked_subprocess(
#     310                     ["latex", "-interaction=nonstopmode", "--halt-on-error",
#     311                      texfile], tex)
#
# ~/opt/miniconda3/envs/denoising/lib/python3.9/site-packages/matplotlib/texmanager.py in _run_checked_subprocess(self, command, tex)
#     277                                              stderr=subprocess.STDOUT)
#     278         except FileNotFoundError as exc:
# --> 279             raise RuntimeError(
#     280                 'Failed to process string with tex because {} could not be '
#     281                 'found'.format(command[0])) from exc
#
# RuntimeError: Failed to process string with tex because latex could not be found
